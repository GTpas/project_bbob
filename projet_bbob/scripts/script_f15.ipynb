# %% [markdown]
# <a href="https://colab.research.google.com/github/GTpas/project_bbob/blob/Marouan/script_f15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import re

files = [
    "../data/data_randomSearch-5/data_f15/bbobexp_f15_DIM2_i1.tdat",
    "../data/data_randomSearch-5/data_f15/bbobexp_f15_DIM3_i1.tdat",
    "../data/data_randomSearch-5/data_f15/bbobexp_f15_DIM10_i1.tdat"
]

def parse_tdat(file_path):
    filtered_data = []
    inside_run = False

    with open(file_path, "r", encoding="utf-8") as file:
        for line in file:
            if line.startswith('%'):
                if inside_run:
                    break
                inside_run = True
                continue

            if inside_run:
                values = line.split()
                if len(values) > 2:
                    try:
                        x_val = float(values[0])
                        y_val = float(values[2])
                        filtered_data.append([x_val, y_val])
                    except ValueError:
                        continue

    return pd.DataFrame(filtered_data,
                        columns=['% function evaluation',
                                 'best noise-free fitness - Fopt'])

n = len(files)
fig, axs = plt.subplots(1, n, figsize=(8*n, 5))

for i, file_path in enumerate(files):
    df = parse_tdat(file_path)
    filename = os.path.basename(file_path)
    match_dim = re.search(r'DIM(\d+)', filename)
    dimension = match_dim.group(1) if match_dim else "?"
    title_str = f"DIM{dimension}_f10 Random- Évolution de la fitness pour le premier run dimension {dimension}"

    axs[i].plot(df['% function evaluation'],
                df['best noise-free fitness - Fopt'],
                '-', markersize=5,
                label='best noise-free fitness - Fopt')
    axs[i].set_xlabel('% function evaluation')
    axs[i].set_ylabel('best noise-free fitness - Fopt')
    axs[i].grid(True)
    axs[i].set_xscale('log')
    axs[i].legend()
    axs[i].set_title(title_str, fontsize=10)

plt.tight_layout()

save_folder = "../figures/figure_f15_randomSearch-5"
os.makedirs(save_folder, exist_ok=True)

save_path = os.path.join(save_folder, "f15_randomSearch_premierRun.png")
plt.savefig(save_path)

plt.show()

# %%
import os
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

files = [
    "project_bbob/data/data_randomSearch-5/data_f15/bbobexp_f15_DIM2_i1.tdat",
    "project_bbob/data/data_randomSearch-5/data_f15/bbobexp_f15_DIM3_i1.tdat",
    "project_bbob/data/data_randomSearch-5/data_f15/bbobexp_f15_DIM10_i1.tdat"
]
def parse_all_runs(file_path):
    all_runs = []
    run_data = []
    inside_run = False
    run_id = 0

    with open(file_path, "r", encoding="utf-8") as file:
        for line in file:
            if line.startswith('% function evaluation'):
                if run_data:
                    df_run = pd.DataFrame(run_data, columns=[
                        '% function evaluation', 'best noise-free fitness - Fopt'])
                    df_run['run_id'] = run_id
                    all_runs.append(df_run)
                    run_data = []
                    run_id += 1
                inside_run = True
                continue
            if inside_run:
                values = line.split()
                if len(values) > 2:
                    try:
                        x_val = float(values[0])
                        y_val = float(values[2])
                        run_data.append([x_val, y_val])
                    except ValueError:
                        continue

    if run_data:
        df_run = pd.DataFrame(run_data, columns=[
            '% function evaluation', 'best noise-free fitness - Fopt'])
        df_run['run_id'] = run_id
        all_runs.append(df_run)

    return all_runs

for file_path in files:
    runs = parse_all_runs(file_path)

    filename = os.path.basename(file_path)
    match_dim = re.search(r'DIM(\d+)', filename)
    dimension = match_dim.group(1) if match_dim else "?"

    fig, axs = plt.subplots(1, 2, figsize=(12, 4), constrained_layout=True)

    for i, df_run in enumerate(runs):
        axs[0].plot(df_run['% function evaluation'],
                    df_run['best noise-free fitness - Fopt'],
                    linestyle='-', linewidth=1, label=f'Run {i+1}')
    axs[0].set_xlabel('% function evaluation')
    axs[0].set_ylabel('best noise-free fitness - Fopt')
    axs[0].set_title(f'DIM{dimension} - Tous les runs')
    axs[0].set_xscale('log')
    axs[0].grid(True)
    axs[0].legend(loc='upper right', fontsize=6, ncol=2, frameon=False)

    common_x = set(runs[0]['% function evaluation'])
    for df_run in runs[1:]:
        common_x &= set(df_run['% function evaluation'])

    if not common_x:
        print(f"❌ Aucun x commun à tous les runs pour DIM{dimension}")
        continue

    filtered_runs = [df[df['% function evaluation'].isin(common_x)] for df in runs]
    df_total = pd.concat(filtered_runs, ignore_index=True)

    stats = df_total.groupby('% function evaluation')['best noise-free fitness - Fopt'].describe(
        percentiles=[0.25, 0.5, 0.75]
    ).rename(columns={
        'count': 'N',
        'mean': 'Moyenne',
        '25%': 'Q1',
        '50%': 'Médiane',
        '75%': 'Q3'
    })

    x_vals = stats.index
    axs[1].plot(x_vals, stats['Moyenne'], '-', color='blue', label='Moyenne', markersize=4)
    axs[1].fill_between(x_vals, stats['Q1'], stats['Q3'], alpha=0.2, color='blue', label='Q1 - Q3')
    axs[1].set_xlabel('% function evaluation')
    axs[1].set_ylabel('best noise-free fitness - Fopt')
    axs[1].set_title(f'DIM{dimension} - Moyenne + Quartiles (x communs)')
    axs[1].set_xscale('log')
    axs[1].grid(True)
    axs[1].legend(loc='upper right', fontsize=6, frameon=False)

    print(f"\n📊 DIM{dimension} - Nombre de points utilisés par x commun :")
    print(stats[['N']].astype(int).transpose())

    save_folder = "project_bbob/figures/figure_f15_randomSearch-5"
    os.makedirs(save_folder, exist_ok=True)
    algo = "ABC"
    save_filename = f"f15_randomSearch_tous_les_runs_DIM{dimension}.png"
    save_path = os.path.join(save_folder, save_filename)
    plt.savefig(save_path)
    print(f"✅ Figure sauvegardée : {save_path}")

    plt.show()
# Out:
# 📊 DIM2 - Nombre de points utilisés par x commun :
# % function evaluation  1.0         2.0         3.0         4.0         \
# N                              15          15          15          15
#
# % function evaluation  5.0         6.0         7.0         8.0         \
# N                              15          15          15          15
#
# % function evaluation  10.0        11.0        ...  7943282.0   8912509.0   \
# N                              15          15  ...          15          15
#
# % function evaluation  10000000.0  11220184.0  12589254.0  14125375.0  \
# N                              15          15          15          15
#
# % function evaluation  15848931.0  17782794.0  19952623.0  20000000.0
# N                              15          15          15          15
#
# [1 rows x 148 columns]
# ✅ Figure sauvegardée : project_bbob/figures/figure_f15_randomSearch-5/f15_randomSearch_tous_les_runs_DIM2.png
# 📊 DIM3 - Nombre de points utilisés par x commun :
# % function evaluation  1.0         2.0         3.0         4.0         \
# N                              15          15          15          15
#
# % function evaluation  5.0         6.0         7.0         8.0         \
# N                              15          15          15          15
#
# % function evaluation  10.0        11.0        ...  12589254.0  14125375.0  \
# N                              15          15  ...          15          15
#
# % function evaluation  15000000.0  15848931.0  17782794.0  19952623.0  \
# N                              15          15          15          15
#
# % function evaluation  22387211.0  25118864.0  28183829.0  30000000.0
# N                              15          15          15          15
#
# [1 rows x 157 columns]
# ✅ Figure sauvegardée : project_bbob/figures/figure_f15_randomSearch-5/f15_randomSearch_tous_les_runs_DIM3.png
# 📊 DIM10 - Nombre de points utilisés par x commun :
# % function evaluation  1.0          2.0          3.0          4.0          \
# N                               15           15           15           15
#
# % function evaluation  5.0          6.0          7.0          8.0          \
# N                               15           15           15           15
#
# % function evaluation  10.0         11.0         ...  39810717.0   \
# N                               15           15  ...           15
#
# % function evaluation  44668359.0   50000000.0   50118723.0   56234132.0   \
# N                               15           15           15           15
#
# % function evaluation  63095734.0   70794578.0   79432823.0   89125093.0   \
# N                               15           15           15           15
#
# % function evaluation  100000000.0
# N                               15
#
# [1 rows x 162 columns]
# ✅ Figure sauvegardée : project_bbob/figures/figure_f15_randomSearch-5/f15_randomSearch_tous_les_runs_DIM10.png
